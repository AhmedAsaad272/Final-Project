# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAsaad272/Final-Project/blob/main/Fine_tune_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%env CUDA_VISIBLE_DEVICES=2

import torch, torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import time
from torchsummary import summary

import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image

# %%
# Applying Transforms to the Data
image_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/Dataset"
# Out:
# testing  training

# %%
# Load the Data

# Set train and valid directory paths

dataset = '/content/drive/My Drive/Dataset'

train_directory = os.path.join(dataset, 'training')
valid_directory = os.path.join(dataset, 'testing')
test_directory = os.path.join(dataset, 'testing')

# Batch size
bs = 32

# Number of classes
num_classes = len(os.listdir(valid_directory))  #10#2#257
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid']),
    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

# Get a mapping of the indices to the class names, in order to see the output classes of the test images.
idx_to_class = {v: k for k, v in data['train'].class_to_idx.items()}
print(idx_to_class)

# Size of Data, to be used for calculating Average Loss and Accuracy
train_data_size = len(data['train'])
valid_data_size = len(data['valid'])
test_data_size = len(data['test'])

# Create iterators for the Data loaded using DataLoader module
train_data_loader = DataLoader(data['train'], batch_size=bs, shuffle=True)
valid_data_loader = DataLoader(data['valid'], batch_size=bs, shuffle=True)
test_data_loader = DataLoader(data['test'], batch_size=bs, shuffle=True)
# Out:
# 5
# {0: 'bracelet', 1: 'earring', 2: 'necklace', 3: 'nose ring', 4: 'ring'}

# %%
print(idx_to_class)
# Out:
# {0: 'bracelet', 1: 'earring', 2: 'necklace', 3: 'nose ring', 4: 'ring'}

# %%
train_data_size, valid_data_size, test_data_size
# Out:
# (3150, 1350, 1350)

# %%
# Load pretrained ResNet50 Model
resnet152 = models.resnet152(pretrained=True)
resnet152 = resnet152.to('cuda:0')

# %%
resnet152
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
resnet152.avgpool
# Out:
# AdaptiveAvgPool2d(output_size=(1, 1))

# %%
# modules=list(resnet152.children())[:-1]
# resnet152= nn.Sequential(*modules)

# %%
# Freeze model parameters
for p in resnet152.parameters():
    p.requires_grad = True

# %%
# Change the final layer of ResNet50 Model for Transfer Learning
fc_inputs = resnet152.fc.in_features

# 2048-256-5
resnet152.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, num_classes), # Since 5 possible outputs
    nn.LogSoftmax(dim=1) # For using NLLLoss()
)

# Convert model to be used on GPU
resnet152 = resnet152.to('cuda:0')

# %%
num_classes
# Out:
# 5

# %%
# Define Optimizer and Loss Function
learning_rate = 0.00001
# loss_func = nn.NLLLoss()
loss_func = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(resnet152.parameters(), lr = learning_rate)

# %%
def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients.
            # PyTorch accumulates all the gradients in the backward pass. 
            # So it is essential to zero them out at the beginning 
            # of the training loop. 
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(valid_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/valid_data_size 
        avg_valid_acc = valid_acc/valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, dataset+'_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Print the model to be trained
#summary(resnet50, input_size=(3, 224, 224), batch_size=bs, device='cuda')

# Train the model for 25 epochs
num_epochs = 100
trained_model, history = train_and_validate(resnet152, loss_func, optimizer, num_epochs)

torch.save(history, dataset+'_history.pt')
# Out:
# Epoch: 1/100
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch : 000, Training: Loss: 1.4462, Accuracy: 48.3492%,
# 		Validation : Loss : 1.2165, Accuracy: 67.8519%, Time: 102.4070s
# Epoch: 2/100
# Epoch : 001, Training: Loss: 0.8657, Accuracy: 80.3175%,
# 		Validation : Loss : 0.7121, Accuracy: 78.0741%, Time: 100.7660s
# Epoch: 3/100
# Epoch : 002, Training: Loss: 0.4151, Accuracy: 90.9206%,
# 		Validation : Loss : 0.5393, Accuracy: 83.7778%, Time: 101.7758s
# Epoch: 4/100
# Epoch : 003, Training: Loss: 0.2055, Accuracy: 96.2222%,
# 		Validation : Loss : 0.5092, Accuracy: 82.6667%, Time: 102.2562s
# Epoch: 5/100
# Epoch : 004, Training: Loss: 0.1174, Accuracy: 97.5556%,
# 		Validation : Loss : 0.5293, Accuracy: 82.9630%, Time: 102.5754s
# Epoch: 6/100
# Epoch : 005, Training: Loss: 0.0754, Accuracy: 98.8254%,
# 		Validation : Loss : 0.5585, Accuracy: 83.4815%, Time: 102.6540s
# Epoch: 7/100
# Epoch : 006, Training: Loss: 0.0681, Accuracy: 98.6032%,
# 		Validation : Loss : 0.5388, Accuracy: 84.2222%, Time: 102.6894s
# Epoch: 8/100
# Epoch : 007, Training: Loss: 0.0573, Accuracy: 98.7619%,
# 		Validation : Loss : 0.5668, Accuracy: 82.0741%, Time: 102.7131s
# Epoch: 9/100
# Epoch : 008, Training: Loss: 0.0440, Accuracy: 99.2381%,
# 		Validation : Loss : 0.6443, Accuracy: 81.2593%, Time: 102.6081s
# Epoch: 10/100
# Epoch : 009, Training: Loss: 0.0369, Accuracy: 99.3968%,
# 		Validation : Loss : 0.6536, Accuracy: 81.7037%, Time: 102.8655s
# Epoch: 11/100
# Epoch : 010, Training: Loss: 0.0311, Accuracy: 99.4921%,
# 		Validation : Loss : 0.6709, Accuracy: 82.2222%, Time: 102.9466s
# Epoch: 12/100
# Epoch : 011, Training: Loss: 0.0280, Accuracy: 99.3651%,
# 		Validation : Loss : 0.6215, Accuracy: 82.2963%, Time: 102.6308s
# Epoch: 13/100
# Epoch : 012, Training: Loss: 0.0274, Accuracy: 99.1746%,
# 		Validation : Loss : 0.7028, Accuracy: 80.2222%, Time: 102.8882s
# Epoch: 14/100
# Epoch : 013, Training: Loss: 0.0279, Accuracy: 99.3968%,
# 		Validation : Loss : 0.7250, Accuracy: 81.6296%, Time: 102.9048s
# Epoch: 15/100
# Epoch : 014, Training: Loss: 0.0182, Accuracy: 99.6825%,
# 		Validation : Loss : 0.6330, Accuracy: 82.8889%, Time: 102.7132s
# Epoch: 16/100
# Epoch : 015, Training: Loss: 0.0155, Accuracy: 99.6190%,
# 		Validation : Loss : 0.6095, Accuracy: 83.2593%, Time: 102.9953s
# Epoch: 17/100
# Epoch : 016, Training: Loss: 0.0116, Accuracy: 99.9048%,
# 		Validation : Loss : 0.6532, Accuracy: 83.3333%, Time: 102.9274s
# Epoch: 18/100
# Epoch : 017, Training: Loss: 0.0114, Accuracy: 99.8413%,
# 		Validation : Loss : 0.6324, Accuracy: 83.5556%, Time: 102.8681s
# Epoch: 19/100
# Epoch : 018, Training: Loss: 0.0172, Accuracy: 99.6508%,
# 		Validation : Loss : 0.7415, Accuracy: 81.4815%, Time: 102.8396s
# Epoch: 20/100
# Epoch : 019, Training: Loss: 0.0141, Accuracy: 99.7143%,
# 		Validation : Loss : 0.7641, Accuracy: 81.2593%, Time: 102.8758s
# Epoch: 21/100
# Epoch : 020, Training: Loss: 0.0152, Accuracy: 99.6190%,
# 		Validation : Loss : 0.8184, Accuracy: 80.8148%, Time: 102.6445s
# Epoch: 22/100
# Epoch : 021, Training: Loss: 0.0144, Accuracy: 99.6190%,
# 		Validation : Loss : 0.7642, Accuracy: 82.0000%, Time: 102.6241s
# Epoch: 23/100
# Epoch : 022, Training: Loss: 0.0154, Accuracy: 99.7143%,
# 		Validation : Loss : 0.7044, Accuracy: 82.7407%, Time: 102.8831s
# Epoch: 24/100
# Epoch : 023, Training: Loss: 0.0179, Accuracy: 99.5873%,
# 		Validation : Loss : 0.7083, Accuracy: 82.9630%, Time: 102.7329s
# Epoch: 25/100
# Epoch : 024, Training: Loss: 0.0104, Accuracy: 99.8413%,
# 		Validation : Loss : 0.7152, Accuracy: 83.9259%, Time: 102.7299s
# Epoch: 26/100
# Epoch : 025, Training: Loss: 0.0109, Accuracy: 99.7460%,
# 		Validation : Loss : 0.6837, Accuracy: 84.3704%, Time: 102.5591s
# Epoch: 27/100
# Epoch : 026, Training: Loss: 0.0165, Accuracy: 99.6825%,
# 		Validation : Loss : 0.7900, Accuracy: 82.3704%, Time: 102.5426s
# Epoch: 28/100
# Epoch : 027, Training: Loss: 0.0138, Accuracy: 99.6508%,
# 		Validation : Loss : 0.8089, Accuracy: 82.2222%, Time: 102.5298s
# Epoch: 29/100
# Epoch : 028, Training: Loss: 0.0131, Accuracy: 99.6825%,
# 		Validation : Loss : 0.7903, Accuracy: 82.4444%, Time: 102.8774s
# Epoch: 30/100
# Epoch : 029, Training: Loss: 0.0134, Accuracy: 99.6825%,
# 		Validation : Loss : 0.8807, Accuracy: 81.1852%, Time: 102.4178s
# Epoch: 31/100
# Epoch : 030, Training: Loss: 0.0060, Accuracy: 99.9365%,
# 		Validation : Loss : 0.8641, Accuracy: 80.5926%, Time: 102.4505s
# Epoch: 32/100
# Epoch : 031, Training: Loss: 0.0053, Accuracy: 99.9683%,
# 		Validation : Loss : 0.7747, Accuracy: 83.0370%, Time: 102.6266s
# Epoch: 33/100
# Epoch : 032, Training: Loss: 0.0045, Accuracy: 99.9048%,
# 		Validation : Loss : 0.8502, Accuracy: 81.3333%, Time: 102.5795s
# Epoch: 34/100
# Epoch : 033, Training: Loss: 0.0061, Accuracy: 99.8413%,
# 		Validation : Loss : 0.8748, Accuracy: 81.4074%, Time: 102.7702s
# Epoch: 35/100
# Epoch : 034, Training: Loss: 0.0069, Accuracy: 99.8730%,
# 		Validation : Loss : 0.7735, Accuracy: 83.1852%, Time: 102.7085s
# Epoch: 36/100
# Epoch : 035, Training: Loss: 0.0063, Accuracy: 99.9683%,
# 		Validation : Loss : 0.8584, Accuracy: 82.4444%, Time: 102.6739s
# Epoch: 37/100
# Epoch : 036, Training: Loss: 0.0032, Accuracy: 99.9365%,
# 		Validation : Loss : 0.8022, Accuracy: 82.6667%, Time: 102.7257s
# Epoch: 38/100
# Epoch : 037, Training: Loss: 0.0029, Accuracy: 99.9683%,
# 		Validation : Loss : 0.8169, Accuracy: 82.5926%, Time: 102.7515s
# Epoch: 39/100
# Epoch : 038, Training: Loss: 0.0027, Accuracy: 99.9683%,
# 		Validation : Loss : 0.8144, Accuracy: 83.2593%, Time: 102.6903s
# Epoch: 40/100
# Epoch : 039, Training: Loss: 0.0074, Accuracy: 99.8413%,
# 		Validation : Loss : 0.8712, Accuracy: 81.7037%, Time: 102.5295s
# Epoch: 41/100
# Epoch : 040, Training: Loss: 0.0072, Accuracy: 99.8413%,
# 		Validation : Loss : 0.9356, Accuracy: 81.5556%, Time: 102.6344s
# Epoch: 42/100
# Epoch : 041, Training: Loss: 0.0139, Accuracy: 99.6508%,
# 		Validation : Loss : 0.8351, Accuracy: 83.4074%, Time: 102.6254s
# Epoch: 43/100
# Epoch : 042, Training: Loss: 0.0081, Accuracy: 99.8413%,
# 		Validation : Loss : 0.8859, Accuracy: 82.8889%, Time: 102.5556s
# Epoch: 44/100
# Epoch : 043, Training: Loss: 0.0041, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9540, Accuracy: 80.5926%, Time: 102.7443s
# Epoch: 45/100
# Epoch : 044, Training: Loss: 0.0047, Accuracy: 99.9683%,
# 		Validation : Loss : 0.8944, Accuracy: 81.1852%, Time: 102.6158s
# Epoch: 46/100
# Epoch : 045, Training: Loss: 0.0044, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9340, Accuracy: 81.1111%, Time: 102.6278s
# Epoch: 47/100
# Epoch : 046, Training: Loss: 0.0063, Accuracy: 99.8413%,
# 		Validation : Loss : 0.8801, Accuracy: 81.3333%, Time: 102.5721s
# Epoch: 48/100
# Epoch : 047, Training: Loss: 0.0077, Accuracy: 99.8095%,
# 		Validation : Loss : 1.0895, Accuracy: 78.8148%, Time: 102.6746s
# Epoch: 49/100
# Epoch : 048, Training: Loss: 0.0064, Accuracy: 99.8095%,
# 		Validation : Loss : 0.9555, Accuracy: 80.8889%, Time: 102.8294s
# Epoch: 50/100
# Epoch : 049, Training: Loss: 0.0053, Accuracy: 99.8413%,
# 		Validation : Loss : 0.9630, Accuracy: 80.4444%, Time: 104.5349s
# Epoch: 51/100
# Epoch : 050, Training: Loss: 0.0053, Accuracy: 99.7778%,
# 		Validation : Loss : 0.8701, Accuracy: 82.9630%, Time: 104.8308s
# Epoch: 52/100
# Epoch : 051, Training: Loss: 0.0070, Accuracy: 99.8730%,
# 		Validation : Loss : 0.8249, Accuracy: 83.3333%, Time: 104.6095s
# Epoch: 53/100
# Epoch : 052, Training: Loss: 0.0044, Accuracy: 99.8730%,
# 		Validation : Loss : 0.8582, Accuracy: 83.7778%, Time: 103.3033s
# Epoch: 54/100
# Epoch : 053, Training: Loss: 0.0029, Accuracy: 99.9365%,
# 		Validation : Loss : 0.8690, Accuracy: 83.1111%, Time: 102.7845s
# Epoch: 55/100
# Epoch : 054, Training: Loss: 0.0091, Accuracy: 99.8413%,
# 		Validation : Loss : 0.9535, Accuracy: 81.3333%, Time: 102.5966s
# Epoch: 56/100
# Epoch : 055, Training: Loss: 0.0044, Accuracy: 99.9048%,
# 		Validation : Loss : 0.8561, Accuracy: 82.8889%, Time: 102.5723s
# Epoch: 57/100
# Epoch : 056, Training: Loss: 0.0099, Accuracy: 99.7778%,
# 		Validation : Loss : 0.9693, Accuracy: 81.4815%, Time: 102.5696s
# Epoch: 58/100
# Epoch : 057, Training: Loss: 0.0045, Accuracy: 99.8730%,
# 		Validation : Loss : 1.0219, Accuracy: 81.0370%, Time: 102.5327s
# Epoch: 59/100
# Epoch : 058, Training: Loss: 0.0023, Accuracy: 100.0000%,
# 		Validation : Loss : 0.9048, Accuracy: 82.5926%, Time: 102.5299s
# Epoch: 60/100
# Epoch : 059, Training: Loss: 0.0033, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9695, Accuracy: 81.4074%, Time: 102.6480s
# Epoch: 61/100
# Epoch : 060, Training: Loss: 0.0060, Accuracy: 99.8413%,
# 		Validation : Loss : 0.9481, Accuracy: 81.8519%, Time: 102.5728s
# Epoch: 62/100
# Epoch : 061, Training: Loss: 0.0027, Accuracy: 99.9683%,
# 		Validation : Loss : 0.9490, Accuracy: 82.0741%, Time: 102.6687s
# Epoch: 63/100
# Epoch : 062, Training: Loss: 0.0114, Accuracy: 99.7460%,
# 		Validation : Loss : 0.9717, Accuracy: 81.8519%, Time: 102.3708s
# Epoch: 64/100
# Epoch : 063, Training: Loss: 0.0060, Accuracy: 99.8413%,
# 		Validation : Loss : 1.1523, Accuracy: 79.5556%, Time: 102.4650s
# Epoch: 65/100
# Epoch : 064, Training: Loss: 0.0056, Accuracy: 99.9365%,
# 		Validation : Loss : 1.0341, Accuracy: 81.4815%, Time: 102.5339s
# Epoch: 66/100
# Epoch : 065, Training: Loss: 0.0083, Accuracy: 99.7143%,
# 		Validation : Loss : 1.0021, Accuracy: 80.2222%, Time: 102.3933s
# Epoch: 67/100
# Epoch : 066, Training: Loss: 0.0039, Accuracy: 99.9683%,
# 		Validation : Loss : 0.9954, Accuracy: 81.4074%, Time: 102.3996s
# Epoch: 68/100
# Epoch : 067, Training: Loss: 0.0038, Accuracy: 99.9048%,
# 		Validation : Loss : 1.1524, Accuracy: 79.4815%, Time: 102.5100s
# Epoch: 69/100
# Epoch : 068, Training: Loss: 0.0046, Accuracy: 99.8413%,
# 		Validation : Loss : 1.0913, Accuracy: 81.0370%, Time: 102.6489s
# Epoch: 70/100
# Epoch : 069, Training: Loss: 0.0012, Accuracy: 99.9683%,
# 		Validation : Loss : 1.0957, Accuracy: 81.4815%, Time: 102.5293s
# Epoch: 71/100
# Epoch : 070, Training: Loss: 0.0010, Accuracy: 100.0000%,
# 		Validation : Loss : 1.0148, Accuracy: 81.8519%, Time: 102.3596s
# Epoch: 72/100
# Epoch : 071, Training: Loss: 0.0026, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0760, Accuracy: 81.4074%, Time: 102.9200s
# Epoch: 73/100
# Epoch : 072, Training: Loss: 0.0022, Accuracy: 99.9365%,
# 		Validation : Loss : 0.9341, Accuracy: 82.5185%, Time: 102.2551s
# Epoch: 74/100
# Epoch : 073, Training: Loss: 0.0025, Accuracy: 99.9683%,
# 		Validation : Loss : 1.0002, Accuracy: 82.0000%, Time: 102.4898s
# Epoch: 75/100
# Epoch : 074, Training: Loss: 0.0037, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0413, Accuracy: 82.3704%, Time: 102.4122s
# Epoch: 76/100
# Epoch : 075, Training: Loss: 0.0021, Accuracy: 99.9365%,
# 		Validation : Loss : 1.0310, Accuracy: 81.7037%, Time: 102.2043s
# Epoch: 77/100
# Epoch : 076, Training: Loss: 0.0015, Accuracy: 100.0000%,
# 		Validation : Loss : 1.0378, Accuracy: 82.3704%, Time: 102.6777s
# Epoch: 78/100
# Epoch : 077, Training: Loss: 0.0010, Accuracy: 99.9683%,
# 		Validation : Loss : 1.0826, Accuracy: 82.0000%, Time: 102.7485s
# Epoch: 79/100
# Epoch : 078, Training: Loss: 0.0016, Accuracy: 99.9683%,
# 		Validation : Loss : 1.0734, Accuracy: 82.1481%, Time: 102.8322s
# Epoch: 80/100
# Epoch : 079, Training: Loss: 0.0017, Accuracy: 99.9365%,
# 		Validation : Loss : 1.0573, Accuracy: 82.2963%, Time: 102.7067s
# Epoch: 81/100
# Epoch : 080, Training: Loss: 0.0032, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0820, Accuracy: 80.7407%, Time: 102.8907s
# Epoch: 82/100
# Epoch : 081, Training: Loss: 0.0020, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0649, Accuracy: 81.9259%, Time: 102.5006s
# Epoch: 83/100
# Epoch : 082, Training: Loss: 0.0010, Accuracy: 100.0000%,
# 		Validation : Loss : 1.0863, Accuracy: 81.9259%, Time: 102.8557s
# Epoch: 84/100
# Epoch : 083, Training: Loss: 0.0086, Accuracy: 99.8095%,
# 		Validation : Loss : 1.0836, Accuracy: 81.4815%, Time: 102.9885s
# Epoch: 85/100
# Epoch : 084, Training: Loss: 0.0036, Accuracy: 99.9365%,
# 		Validation : Loss : 1.1166, Accuracy: 80.8889%, Time: 102.6168s
# Epoch: 86/100
# Epoch : 085, Training: Loss: 0.0035, Accuracy: 99.8413%,
# 		Validation : Loss : 1.0628, Accuracy: 82.3704%, Time: 102.8442s
# Epoch: 87/100
# Epoch : 086, Training: Loss: 0.0027, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0215, Accuracy: 82.5926%, Time: 102.7763s
# Epoch: 88/100
# Epoch : 087, Training: Loss: 0.0078, Accuracy: 99.7143%,
# 		Validation : Loss : 1.1546, Accuracy: 82.0741%, Time: 102.6400s
# Epoch: 89/100
# Epoch : 088, Training: Loss: 0.0095, Accuracy: 99.7778%,
# 		Validation : Loss : 1.0045, Accuracy: 82.7407%, Time: 102.8511s
# Epoch: 90/100
# Epoch : 089, Training: Loss: 0.0044, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0067, Accuracy: 81.5556%, Time: 102.4321s
# Epoch: 91/100
# Epoch : 090, Training: Loss: 0.0040, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9125, Accuracy: 83.5556%, Time: 102.2839s
# Epoch: 92/100
# Epoch : 091, Training: Loss: 0.0076, Accuracy: 99.8095%,
# 		Validation : Loss : 0.8364, Accuracy: 82.8148%, Time: 103.0710s
# Epoch: 93/100
# Epoch : 092, Training: Loss: 0.0085, Accuracy: 99.7778%,
# 		Validation : Loss : 1.0730, Accuracy: 81.3333%, Time: 103.0334s
# Epoch: 94/100
# Epoch : 093, Training: Loss: 0.0054, Accuracy: 99.8413%,
# 		Validation : Loss : 1.0522, Accuracy: 81.4074%, Time: 102.4119s
# Epoch: 95/100
# Epoch : 094, Training: Loss: 0.0045, Accuracy: 99.8730%,
# 		Validation : Loss : 0.9704, Accuracy: 83.0370%, Time: 103.0729s
# Epoch: 96/100
# Epoch : 095, Training: Loss: 0.0032, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9573, Accuracy: 81.9259%, Time: 102.4526s
# Epoch: 97/100
# Epoch : 096, Training: Loss: 0.0024, Accuracy: 99.9048%,
# 		Validation : Loss : 1.0271, Accuracy: 80.0741%, Time: 102.3183s
# Epoch: 98/100
# Epoch : 097, Training: Loss: 0.0037, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9406, Accuracy: 81.9259%, Time: 102.6902s
# Epoch: 99/100
# Epoch : 098, Training: Loss: 0.0022, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9712, Accuracy: 82.3704%, Time: 102.2857s
# Epoch: 100/100
# Epoch : 099, Training: Loss: 0.0023, Accuracy: 99.9048%,
# 		Validation : Loss : 0.9845, Accuracy: 81.1852%, Time: 102.8196s

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %%
 def computeTestSetAccuracy(model, loss_criterion):
    '''
    Function to compute the accuracy on the test set
    Parameters
        :param model: Model to test
        :param loss_criterion: Loss Criterion to minimize
    '''

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    test_acc = 0.0
    test_loss = 0.0

    # Validation - No gradient tracking needed
    with torch.no_grad():

        # Set to evaluation mode
        model.eval()

        # Validation loop
        for j, (inputs, labels) in enumerate(test_data_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)

            # Compute loss
            loss = loss_criterion(outputs, labels)

            # Compute the total loss for the batch and add it to valid_loss
            test_loss += loss.item() * inputs.size(0)

            # Calculate validation accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            # Compute total accuracy in the whole batch and add to valid_acc
            test_acc += acc.item() * inputs.size(0)

            print("Test Batch number: {:03d}, Test: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))

    # Find average test loss and test accuracy
    avg_test_loss = test_loss/test_data_size 
    avg_test_acc = test_acc/test_data_size

    print("Test accuracy : " + str(avg_test_acc))

# %%
def predict(model, test_image_name):
    '''
    Function to predict the class of a single test image
    Parameters
        :param model: Model to test
        :param test_image_name: Test image

    '''
    
    transform = image_transforms['test']

    test_image = Image.open(test_image_name)
    plt.imshow(test_image)
    
    test_image_tensor = transform(test_image)

    if torch.cuda.is_available():
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224).cuda()
    else:
        test_image_tensor = test_image_tensor.view(1, 3, 224, 224)
    
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        out = model(test_image_tensor)
        ps = torch.exp(out)
        topk, topclass = ps.topk(3, dim=1)
        for i in range(3):
            print("Predcition", i+1, ":", idx_to_class[topclass.cpu().numpy()[0][i]], ", Score: ", topk.cpu().numpy()[0][i])

# %%
# Test a particular model on a test image

dataset = '/content/drive/My Drive/test/'
model = torch.load('/content/drive/My Drive/Dataset_model_66.pt')
predict(model, dataset+'test2.jpg')       

# Load Data from folders
computeTestSetAccuracy(model, loss_func)
# Out:
# Predcition 1 : bracelet , Score:  0.99502605
# Predcition 2 : nose ring , Score:  0.0042862725
# Predcition 3 : earring , Score:  0.000313983
# Test Batch number: 000, Test: Loss: 1.8404, Accuracy: 0.7188
# Test Batch number: 001, Test: Loss: 1.0237, Accuracy: 0.8750
# Test Batch number: 002, Test: Loss: 0.4570, Accuracy: 0.8438
# Test Batch number: 003, Test: Loss: 1.3726, Accuracy: 0.7500
# Test Batch number: 004, Test: Loss: 0.7417, Accuracy: 0.8125
# Test Batch number: 005, Test: Loss: 1.8331, Accuracy: 0.6562
# Test Batch number: 006, Test: Loss: 0.8963, Accuracy: 0.7812
# Test Batch number: 007, Test: Loss: 0.0943, Accuracy: 0.9688
# Test Batch number: 008, Test: Loss: 0.9665, Accuracy: 0.7812
# Test Batch number: 009, Test: Loss: 1.7369, Accuracy: 0.7812
# Test Batch number: 010, Test: Loss: 1.7403, Accuracy: 0.7188
# Test Batch number: 011, Test: Loss: 1.4401, Accuracy: 0.6875
# Test Batch number: 012, Test: Loss: 1.4047, Accuracy: 0.7812
# Test Batch number: 013, Test: Loss: 0.1217, Accuracy: 0.9375
# Test Batch number: 014, Test: Loss: 1.5242, Accuracy: 0.6562
# Test Batch number: 015, Test: Loss: 1.2238, Accuracy: 0.7500
# Test Batch number: 016, Test: Loss: 1.3990, Accuracy: 0.8438
# Test Batch number: 017, Test: Loss: 1.1114, Accuracy: 0.8438
# Test Batch number: 018, Test: Loss: 1.7350, Accuracy: 0.7188
# Test Batch number: 019, Test: Loss: 0.2836, Accuracy: 0.9375
# Test Batch number: 020, Test: Loss: 0.7582, Accuracy: 0.7500
# Test Batch number: 021, Test: Loss: 0.9548, Accuracy: 0.7812
# Test Batch number: 022, Test: Loss: 1.2644, Accuracy: 0.7812
# Test Batch number: 023, Test: Loss: 0.8275, Accuracy: 0.9062
# Test Batch number: 024, Test: Loss: 1.0141, Accuracy: 0.8438
# Test Batch number: 025, Test: Loss: 0.5413, Accuracy: 0.8438
# Test Batch number: 026, Test: Loss: 0.5115, Accuracy: 0.9062
# Test Batch number: 027, Test: Loss: 0.3986, Accuracy: 0.9375
# Test Batch number: 028, Test: Loss: 0.8501, Accuracy: 0.7500
# Test Batch number: 029, Test: Loss: 0.8464, Accuracy: 0.8125
# Test Batch number: 030, Test: Loss: 0.9876, Accuracy: 0.8125
# Test Batch number: 031, Test: Loss: 0.9582, Accuracy: 0.7500
# Test Batch number: 032, Test: Loss: 0.5787, Accuracy: 0.9062
# Test Batch number: 033, Test: Loss: 0.7665, Accuracy: 0.8438
# Test Batch number: 034, Test: Loss: 0.0832, Accuracy: 0.9688
# Test Batch number: 035, Test: Loss: 1.4893, Accuracy: 0.7500
# Test Batch number: 036, Test: Loss: 1.4123, Accuracy: 0.8125
# Test Batch number: 037, Test: Loss: 1.3290, Accuracy: 0.7188
# Test Batch number: 038, Test: Loss: 0.7228, Accuracy: 0.9062
# Test Batch number: 039, Test: Loss: 1.4649, Accuracy: 0.8125
# Test Batch number: 040, Test: Loss: 0.6874, Accuracy: 0.8438
# Test Batch number: 041, Test: Loss: 0.5700, Accuracy: 0.9062
# Test Batch number: 042, Test: Loss: 0.1590, Accuracy: 0.8333
# Test accuracy : 0.8140740739857709
